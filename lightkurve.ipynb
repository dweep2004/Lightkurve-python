# %%
import lightkurve as lk
import matplotlib as plt

# %%
tpf=lk.search_targetpixelfile('Kepler-8', quarter=10).download()
tpf.plot();
# Out:
# C:\Users\dweep\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lightkurve\search.py:424: LightkurveWarning: Warning: 4 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
lcf = lk.search_lightcurve('Kepler-8', quarter=10).download()
lcf.plot();
# Out:
# C:\Users\dweep\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lightkurve\search.py:424: LightkurveWarning: Warning: 5 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
lcf = lk.search_lightcurve('Kepler-8', quarter=10, campaign=1).download()
lcf.plot();
# Out:
# No data found for target "Kepler-8".
# C:\Users\dweep\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lightkurve\search.py:419: LightkurveWarning: Cannot download from an empty search result.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 lcf = lk.search_lightcurve('Kepler-8', quarter=10, campaign=1).download()
# ----> 2 lcf.plot();
#
# AttributeError: 'NoneType' object has no attribute 'plot'
